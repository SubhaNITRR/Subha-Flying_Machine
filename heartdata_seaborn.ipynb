# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(sns.__version__)
# Out:
# 0.10.0

# %%
heart=pd.read_csv(r'D:\data science project data\clevelanda.csv')

# %%
heart.head(4)
# Out:
#    age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0   63       1   1       145   233    1        2      150      0      2.3
# 1   67       1   4       160   286    0        2      108      1      1.5
# 2   67       1   4       120   229    0        2      129      1      2.6
# 3   37       1   3       130   250    0        0      187      0      3.5
#
#    slope ca thal  class
# 0      3  0    6      0
# 1      2  3    3      2
# 2      2  2    7      1
# 3      3  0    3      0

# %%
heart.tail(5)
# Out:
#      age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 298   45       1   1       110   264    0        0      132      0      1.2
# 299   68       1   4       144   193    1        0      141      0      3.4
# 300   57       1   4       130   131    0        0      115      1      1.2
# 301   57       0   2       130   236    0        2      174      0      0.0
# 302   38       1   3       138   175    0        0      173      0      0.0
#
#      slope ca thal  class
# 298      2  0    7      1
# 299      2  2    7      2
# 300      2  1    7      3
# 301      2  1    3      1
# 302      1  ?    3      0

# %%
heart.columns
# Out:
# Index(['age', 'gender', 'cp', 'trestbps', 'chol', 'fps', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'class'],
#       dtype='object')

# %%
sns.lineplot(x=heart['age'],y=heart['thalach'])

# %%
sns.lineplot(x=heart['age'],y=heart['chol'],color='c')

# %%
plt.figure(figsize=(8,6))
sns.lineplot(x=heart['age'],y=heart['trestbps'],color='g')

# %%
plt.figure(figsize=(8,6))
sns.countplot(heart['class'],color='k')

# %%
plt.figure(figsize=(8,6))
sns.countplot(heart['fps'],color='m')

# %%
heart.head(5)
# Out:
#    age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0   63       1   1       145   233    1        2      150      0      2.3
# 1   67       1   4       160   286    0        2      108      1      1.5
# 2   67       1   4       120   229    0        2      129      1      2.6
# 3   37       1   3       130   250    0        0      187      0      3.5
# 4   41       0   2       130   204    0        2      172      0      1.4
#
#    slope ca thal  class
# 0      3  0    6      0
# 1      2  3    3      2
# 2      2  2    7      1
# 3      3  0    3      0
# 4      1  0    3      0

# %%
plt.figure(figsize=(8,6))
sns.countplot(heart['cp'])

# %%
plt.figure(figsize=(7,5))
sns.countplot(heart['thal'])

# %%
plt.figure(figsize=(7,5))
sns.countplot(heart['gender'])

# %%
plt.figure(figsize=(10,8))
sns.barplot(x=heart['gender'],y=heart['thalach'])

# %%
plt.figure(figsize=(7,5))
sns.barplot(x=heart['class'],y=heart['thalach'])

# %%
plt.figure(figsize=(7,5))
sns.barplot(x=heart['class'],y=heart['age'])

# %%
plt.figure(figsize=(12,8))
sns.boxplot(heart['age'])

# %%
heart['age'].describe()
# Out:
# count    303.000000
# mean      54.438944
# std        9.038662
# min       29.000000
# 25%       48.000000
# 50%       56.000000
# 75%       61.000000
# max       77.000000
# Name: age, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.boxplot(heart['trestbps'])

# %%
heart['trestbps'].describe()
# Out:
# count    303.000000
# mean     131.689769
# std       17.599748
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
plt.figure(figsize=(10,8))
sns.boxplot(heart['chol'])

# %%
heart['chol'].describe()
# Out:
# count    303.000000
# mean     246.693069
# std       51.776918
# min      126.000000
# 25%      211.000000
# 50%      241.000000
# 75%      275.000000
# max      564.000000
# Name: chol, dtype: float64

# %%
heart.head(5)
# Out:
#    age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0   63       1   1       145   233    1        2      150      0      2.3
# 1   67       1   4       160   286    0        2      108      1      1.5
# 2   67       1   4       120   229    0        2      129      1      2.6
# 3   37       1   3       130   250    0        0      187      0      3.5
# 4   41       0   2       130   204    0        2      172      0      1.4
#
#    slope ca thal  class
# 0      3  0    6      0
# 1      2  3    3      2
# 2      2  2    7      1
# 3      3  0    3      0
# 4      1  0    3      0

# %%
plt.figure(figsize=(10,8))
sns.scatterplot(x=heart['age'],y=heart['trestbps'])

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x=heart['age'],y=heart['thalach'])

# %%
plt.figure(figsize=(8,6))
sns.heatmap(heart.corr(),annot=True)

# %%
plt.figure(figsize=(7,5))
sns.distplot(heart['age'])

# %%
plt.figure(figsize=(7,5))
sns.distplot(heart['chol'])
