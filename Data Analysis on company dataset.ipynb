# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
comp=pd.read_csv(r'D:\data science project data\Company_Data.csv')

# %%
comp.head(5)
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0   9.50        138      73           11         276    120   42         17
# 1  11.22        111      48           16         260     83   65         10
# 2  10.06        113      35           10         269     80   59         12
# 3   7.40        117     100            4         466     97   55         14
# 4   4.15        141      64            3         340    128   38         13
#
#   Urban   US
# 0   Yes  Yes
# 1   Yes  Yes
# 2   Yes  Yes
# 3   Yes  Yes
# 4   Yes   No

# %%
plt.figure(figsize=(7,5))
sns.boxplot(comp['Sales'])

# %%
comp['Sales'].describe()
# Out:
# count    400.000000
# mean       7.496325
# std        2.824115
# min        0.000000
# 25%        5.390000
# 50%        7.490000
# 75%        9.320000
# max       16.270000
# Name: Sales, dtype: float64

# %%
sns.countplot(comp['US'])

# %%
sns.scatterplot(x=comp['CompPrice'],y=comp['Price'])

# %%
sns.lineplot(x=comp['Sales'],y=comp['Price'])

# %%
sns.lineplot(x=comp['Advertising'],y=comp['CompPrice'])

# %%
sns.boxplot(comp['Advertising'])

# %%
sns.distplot(comp['Sales'])

# %%
sns.countplot(comp['Urban'])

# %%
sns.barplot(x=comp['Urban'],y=comp['Sales'])

# %%
sns.boxplot(comp['Age'])

# %%
sns.heatmap(comp.corr())

# %%
sns.scatterplot(x=comp['Sales'],y=comp['Advertising'])

# %%
sns.lmplot(data=comp,x='Sales',y='Advertising')
